# %% [markdown]
# While developing the app, I want to check how the dataframes look like and test small scripts; I will do it on here!

# %%
import pandas as pd

ticker = "EURUSD=X"
desc = "complete"

pred_data = pd.read_parquet(f"../data/prediction_data/{ticker}_predictions_data_{desc}").sort_values(by='date', ascending=False)
# Out:
#          date  high_pred  low_pred  sentiment_polarity_pred  open_pred  \
# 7  2025-04-15   0.907466  0.898094                 0.728575   0.900937
# 6  2025-04-14   0.908670  0.900406                 0.719408   0.903587
# 5  2025-04-13   0.909352  0.900208                 0.723428   0.904292
# 4  2025-04-12   0.900428  0.892085                 0.760622   0.903077
# 3  2025-04-11   0.902387  0.893975                 0.756818   0.904119
# 2  2025-04-10   0.911534  0.902897                 0.706580   0.906406
# 1  2025-04-09   0.912623  0.903709                 0.687794   0.907526
# 0  2025-04-08   0.912946  0.903994                 0.726804   0.907276
#
#    close_pred  sentiment_polarity_sma_pred  high_sma_pred  low_sma_pred  \
# 7    0.901308                     0.682782       0.908903      0.901947
# 6    0.903939                     0.685482       0.910321      0.903369
# 5    0.904625                     0.685947       0.911330      0.904353
# ...

# %%
from datetime import datetime

today = datetime.today().date()
print(today)
# Out:
# 2025-04-09

# %%
import pandas as pd

ticker = "EURUSD=X"
desc = "complete"

err_data = pd.read_parquet(f"../data/error_data/{ticker}_error_data_{desc}").sort_values(by='date', ascending=False)

print(err_data.iloc[0,-2])
print(err_data.iloc[0,-1])
err_data
# Out:
# 1.1058276891708374
# 1.0957703590393066
#          date  high_pred  low_pred  sentiment_polarity_pred  open_pred  \
# 1  2025-04-09   0.912623  0.903709                 0.687794   0.907526
# 0  2025-04-08   0.912946  0.903994                 0.726804   0.907276
#
#    close_pred  sentiment_polarity_sma_pred  high_sma_pred  low_sma_pred  \
# 1    0.907786                     0.684874       0.915984      0.909096
# 0    0.907522                     0.686044       0.917133      0.910290
#
#    open_sma_pred  close_sma_pred  high_real  low_real
# 1       0.912918        0.912919   1.105828  1.095770
# 0       0.914084        0.914087   0.918156  0.909786

# %%
import pandas as pd

ticker = "EURUSD=X"
desc = "complete"

pd.read_parquet(f"../data/modelling_dataset/{ticker}_modelling_dataset").sort_values(by='date', ascending=False)
# Out:
#           date  sentiment_polarity      High       Low      Open     Close  \
# 125 2025-04-08            0.671861  0.918156  0.909786  0.916238  0.916238
# 124 2025-04-07            0.734600  0.917263  0.904986  0.910531  0.910531
# 123 2025-04-04            0.691375  0.912101  0.900406  0.905387  0.905551
# 122 2025-04-03            0.758440  0.919050  0.898457  0.917011  0.917011
# 121 2025-04-02            0.781711  0.927498  0.919760  0.926381  0.926381
# ..         ...                 ...       ...       ...       ...       ...
# 8   2024-10-21            0.730683  0.924300  0.920107  0.920141  0.920141
# 7   2024-10-18            0.663025  0.923702  0.920539  0.923480  0.923480
# 6   2024-10-17            0.712921  0.924907  0.920209  0.920955  0.920955
# 5   2024-10-16            0.582101  0.920133  0.917372  0.918814  0.918814
# 4   2024-10-15            0.746610  0.918687  0.916078  0.916708  0.916708
#
#      sentiment_polarity_sma  High_sma   Low_sma  Open_sma  Close_sma
# ...

# %%
import pandas as pd 

pd.read_parquet(r"C:\Users\sumag\Downloads\EURUSD=X_modelling_dataset")
# Out:
#           date  sentiment_polarity      High       Low      Open     Close  \
# 125 2025-04-08            0.671861  0.918156  0.909786  0.916238  0.916238
# 124 2025-04-07            0.734600  0.917263  0.904986  0.910531  0.910531
# 123 2025-04-04            0.691375  0.912101  0.900406  0.905387  0.905551
# 122 2025-04-03            0.758440  0.919050  0.898457  0.917011  0.917011
# 121 2025-04-02            0.781711  0.927498  0.919760  0.926381  0.926381
# ..         ...                 ...       ...       ...       ...       ...
# 8   2024-10-21            0.730683  0.924300  0.920107  0.920141  0.920141
# 7   2024-10-18            0.663025  0.923702  0.920539  0.923480  0.923480
# 6   2024-10-17            0.712921  0.924907  0.920209  0.920955  0.920955
# 5   2024-10-16            0.582101  0.920133  0.917372  0.918814  0.918814
# 4   2024-10-15            0.746610  0.918687  0.916078  0.916708  0.916708
#
#      sentiment_polarity_sma  High_sma   Low_sma  Open_sma  Close_sma
# ...
